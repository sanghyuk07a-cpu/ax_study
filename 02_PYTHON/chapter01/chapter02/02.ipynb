# %% [markdown]
# 2장 2강
# 1.파이썬의 기본 자료형(Primitive Data Types)

# %% [markdown]
# - 자료: 연산에 필요한 데이터 값
# - 자료형: 값의 유형(데이터의 종류)
#
# #### 자료형
# - 숫자형: 자료형(int, 10, 20, ...), 실수형(float, 10.123, ..)
# - 논리형: 참(True), 거짓(False)
# - 문자형: 문자, 문장, ' ', " " 감싸서 선언(한줄), """ ... """ - 여러줄 문장
# - 갑 없음: None

# %%
money = None

# %%
message = """안녕하세요.
반갑습니다.
"""
type(message)
# Out:
# str

# %% [markdown]
# 2장 2강: 기본 자료형과 형변환

# %% [markdown]
# 연산은 같은 자료형끼리 가능
#
# 형변환 함수
# - int(..) : 정수로 변환
# - float(..) : 실수로 변화
# - bool(...) : True, False로 변환
# - str(...) : 문자형으로 변환

# %% [markdown]
# 0.주석(comment )

# %% [markdown]
# 코드 상에 설명을 추가할때 사용, 인터프리터가 해석 하지 않는다.
# - \# : 한줄 주석
# - """ ... """ : 여러줄 주석

# %%
# 코드 설명...
"""
한줄
두줄
세줄
"""
# Out:
# '\n한줄\n두줄\n세줄\n'

# %% [markdown]
# 2.명시적 형변환 (Expiicit Conversion)

# %%
num = "100"
type(num)
# Out:
# str

# %%
"현재 시간은 " + str(10) + "시"
# Out:
# '현재 시간은 10시'

# %% [markdown]
# 3.묵시적 형변환(IMpicit Typr Conversion)

# %%
num1 = 100
nunm2 = 3.123

type(num1), type(nunm2)
# Out:
# (int, float)

# %%
num3 = num1 + nunm2 #num1이 int -> float로 변환되어 계산됨(묵시적 형변환)

num3, num1 + int(num3)

# %%
4.형변환 시 주의해야 할 예외와 원리

# %%
time = "10시"
if time.isdigit():
    int(time) + 1

# %% [markdown]
# 0,'',[],None

# %%
type(message)
# Out:
# str

# %%
result = bool(message) #문자열이 비어있지 않으므로 True
result, type(result)
# Out:
# (True, bool)
