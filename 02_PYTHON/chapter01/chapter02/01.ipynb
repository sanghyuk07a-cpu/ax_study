# %%
x = 5000
x
# Out:
# 5000

# %%
id(x)
# Out:
# 2509171843920

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 2509171843920

# %%
a=10
id(a)
# Out:
# 140707494237384

# %%
a=20
id(a)
# Out:
# 140707494237704

# %%
a=10
id(a)
# Out:
# 140707494237384

# %%
number_of_students = 100

# %%
type(number_of_students)
# Out:
# int

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
result =  True
type(result)
# Out:
# bool

# %%
pi = "원주율"
type(pi)
# Out:
# str
