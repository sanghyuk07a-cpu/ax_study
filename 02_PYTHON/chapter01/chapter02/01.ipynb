# %%
x = 5000
x
# Out:
# 5000

# %%
id(x)
# Out:
# 2509171843920

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 2509171843920

# %%
a=10
id(a)
# Out:
# 140707494237384

# %%
a=20
id(a)
# Out:
# 140707494237704

# %%
a=10
id(a)
# Out:
# 140707494237384
