# %% [markdown]
# # 1장 3강

# %%
print("hello")
# Out:
# hello

# %%
print("world")
# Out:
# world

# %%
print("everyone")
# Out:
# everyone

# %%
print(money)
# Out:
# 5000

# %%
money = 5000

# %% [markdown]
# money = money+2000
# print(money)
