# %%
money = none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 money = none
#
# NameError: name 'none' is not defined

# %%
money = None

# %%
message = """Yo, what's up?
How are you doing?
I hope you're having a great day!"""
Type(message)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 message = """Yo, what's up?
#       2 How are you doing?
#       3 I hope you're having a great day!"""
# ----> 4 Type(message)
#
# NameError: name 'Type' is not defined

# %%
message = """Yo, what's up?
How are you doing?
I hope you're having a great day!"""
type(message)
# Out:
# str

# %%
"현재 시간은 " + str(10) + "시" + "입니다."
# Out:
# '현재 시간은 10시입니다.'

# %%
-int(4.13)
# Out:
# -4

# %%
num1 = 40

result1 = num1 > 30
result2 = num1 < 60

result1 and result2
# Out:
# True

# %%
height = 170

result = height >= 170 and "크다"
result
# Out:
# '크다'

# %%
message = "My name is %s, and I am %d years old."

message % ("Alice", 30)
# Out:
# 'My name is Alice, and I am 30 years old.'
